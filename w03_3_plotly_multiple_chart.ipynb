# %% [markdown]
# <a href="https://colab.research.google.com/github/kmahatma/ssmi-patternrecognition/blob/main/w03_3_plotly_multiple_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🚀 Google Drive Setup
from google.colab import drive
drive.mount('/content/drive')

# Set the default working directory
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3. Using Plotly

# %% [markdown]
# **Example**

# %% [markdown]
# **3.1 Scatter Plot**

# %%
import plotly.express as px
import pandas as pd

# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/" # Change this!
data = pd.read_csv(data_path + "tips.csv")

# plotting the scatter chart
fig = px.scatter(data, x="day", y="tip", color='sex')


# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **3.2 Line Char**

# %%
import plotly.express as px
import pandas as pd

# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/" # Change this!
data = pd.read_csv(data_path + "tips.csv")

# plotting the scatter chart
fig = px.line(data, y='tip', color='sex')

# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **3.3 Bar Chart**

# %%
import plotly.express as px
import pandas as pd

# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/" # Change this!
data = pd.read_csv(data_path + "tips.csv")

# plotting the scatter chart
fig = px.bar(data, x='day', y='tip', color='sex')

# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **1.5 Histogram**

# %%
import plotly.express as px
import pandas as pd

# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/" # Change this!
data = pd.read_csv(data_path + "tips.csv")

# plotting the scatter chart
fig = px.histogram(data, x='total_bill', color='sex')

# showing the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Improved code, showing maximum capability of PLOTLY

# %%
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# Load the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/"  # Change this if needed
data = pd.read_csv(data_path + "tips.csv")

# Convert categorical columns to string
data["day"] = data["day"].astype(str)
data["sex"] = data["sex"].astype(str)
data["smoker"] = data["smoker"].astype(str)

# Create an interactive dropdown visualization
fig = go.Figure()

# Add Bar Chart
fig.add_trace(go.Bar(
    x=data['day'],
    y=data['tip'],
    marker=dict(color=data['size'], colorscale='Viridis'),
    text=data['sex'],
    hoverinfo='text+y'
))

# Add Scatter Plot for More Interactivity
fig.add_trace(go.Scatter(
    x=data['day'],
    y=data['tip'],
    mode='markers',
    marker=dict(size=data['size'] * 5, color=data['size'], colorscale='Plasma', opacity=0.7),
    text=[f"Sex: {s}, Smoker: {sm}" for s, sm in zip(data['sex'], data['smoker'])],
    hoverinfo='text+y'
))

# Set Layout with Interactive Dropdown
fig.update_layout(
    title="💰 Interactive Analysis of Tips by Day",
    xaxis=dict(title="Day of the Week"),
    yaxis=dict(title="Tip Amount ($)"),
    updatemenus=[
        {
            "buttons": [
                {"label": "Bar Chart", "method": "update", "args": [{"visible": [True, False]}]},
                {"label": "Scatter Chart", "method": "update", "args": [{"visible": [False, True]}]},
                {"label": "Both", "method": "update", "args": [{"visible": [True, True]}]}
            ],
            "direction": "down",
            "showactive": True
        }
    ]
)

# Show plot
fig.show()

# Extra Visualizations (for more insights)
px.box(data, x="day", y="tip", color="sex", title="Box Plot: Tip Amount by Day & Gender").show()
px.violin(data, x="day", y="tip", color="sex", box=True, title="Violin Plot: Tip Distribution").show()
px.sunburst(data, path=["day", "sex", "smoker"], values="tip", title="Sunburst Chart: Tips Breakdown").show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
