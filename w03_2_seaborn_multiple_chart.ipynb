# %% [markdown]
# <a href="https://colab.research.google.com/github/kmahatma/ssmi-patternrecognition/blob/main/w03_2_seaborn_multiple_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🚀 Google Drive Setup
from google.colab import drive
drive.mount('/content/drive')

# Set the default working directory
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Using Seaborn

# %% [markdown]
# **2.1 Line Plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/" # Change this!
data = pd.read_csv(data_path + "tips.csv")

# draw lineplot
sns.lineplot(x="sex", y="total_bill", data=data)

# setting the title using Matplotlib
plt.title('Title using Matplotlib Function')

plt.show()

# %% [markdown]
# **2.2  Bar Chart**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/" # Change this!
data = pd.read_csv(data_path + "tips.csv")


sns.barplot(x='day',y='tip', data=data,
            hue='sex')
plt.title("Bar Chart - Tips by Gender")

plt.show()

# %% [markdown]
# **2.3.A Histogram**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/"  # Change this if needed
data = pd.read_csv(data_path + "tips.csv")

sns.histplot(x='total_bill', data=data, kde=True, hue='sex')

plt.show()

# %% [markdown]
# **2.3.B Histogram**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/"  # Change this if needed
data = pd.read_csv(data_path + "tips.csv")

# Set the style for better visualization
sns.set_style("whitegrid")

# Create histogram with seaborn
plt.figure(figsize=(8, 5))
sns.histplot(data, x="tip", hue="sex", kde=True, bins=15, multiple="stack", palette="pastel")

# Set labels and title
plt.xlabel("Tip Amount ($)")
plt.ylabel("Frequency")
plt.title("Histogram of Tips by Gender")

# Show the plot
plt.show()
