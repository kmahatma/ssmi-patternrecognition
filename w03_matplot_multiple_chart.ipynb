# %% [markdown]
# <a href="https://colab.research.google.com/github/kmahatma/ssmi-patternrecognition/blob/main/w03_matplot_multiple_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 🚀 Google Drive Setup
from google.colab import drive
drive.mount('/content/drive')

# Set the default working directory
# Out:
# Mounted at /content/drive

# %%
# 📌 Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Using Matploblib

# %% [markdown]
# **1.3 Scatter Plot**

# %%
# reading the database# Load the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/"
file_name = "tips.csv"

# Check if the file exists before reading
if os.path.exists(data_path + file_name):
    data = pd.read_csv(data_path + file_name)
else:
    raise FileNotFoundError(f"File not found: {data_path + file_name}")

# Scatter plot with day against tip
plt.plot(data['tip'])
plt.plot(data['size'])

# Adding Title to the Plot
plt.title("Scatter Plot")

# Setting the X and Y labels
plt.xlabel('Day')
plt.ylabel('Tip')

plt.show()

# %% [markdown]
# **1.4  Bar Chart**

# %%
# Bar chart
plt.bar(data['day'], data['tip'])

# Adding Title to the Plot
plt.title("Bar Chart")
# Out:
# Text(0.5, 1.0, 'Bar Chart')

# %% [markdown]
# 1.5 Histogram

# %%
import pandas as pd
import matplotlib.pyplot as plt

# reading the data
data_path = "/content/drive/MyDrive/Colab Notebooks/ssmi-pattern-recognition/prak-03-data/"
file_name = "tips.csv"

data = pd.read_csv(data_path + file_name)


# histogram of total_bills
plt.hist(data['total_bill'])

plt.title("Histogram")

# Adding the legends
plt.show()
