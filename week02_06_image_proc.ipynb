# %% [markdown]
# <a href="https://colab.research.google.com/github/kmahatma/ssmi-patternrecognition/blob/main/week02_06_image_proc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operasi image pada Python
# Instalasi paket open cv
# pip install opencv-contrib-python

# pilihan load image (contoh logo ipb)
import matplotlib.pyplot as plt
import cv2
import numpy as np


# dir path
file_path = "/content/drive/MyDrive/@-ssmi-pattern-recognition/prak-02/"

print("read images using opencv")
five = cv2.imread(file_path + "5.png")
print("Image shape:", five.shape)  # (height, width, channels)
print("Image size (total pixels):", five.size)

plt.imshow(five)
cv2.waitKey(0)
# Out:
# read images using opencv
# Image shape: (402, 410, 3)
# Image size (total pixels): 494460
# -1
